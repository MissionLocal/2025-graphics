# %%
import pandas as pd

# %%
! ls
# Out:
# Budget_2026.json data.ipynb       index.html

# %%
# read json 

df = pd.read_json('Budget_2026.json')

# %%
df
# Out:
#                                                   name          size  \
# 0                                                flare           NaN
# 1       flare.Culture & Recreation.Academy of Sciences  7.658802e+06
# 2              flare.Public Protection.Adult Probation  6.159768e+07
# 3    flare.Public Works, Transportation & Commerce....  2.003763e+09
# 4           flare.Culture & Recreation.Arts Commission  2.991130e+07
# ..                                                 ...           ...
# 109                    flare.Public Protection.Sheriff           NaN
# 110            flare.Public Protection.Fire Department           NaN
# 111            flare.Public Protection.Adult Probation           NaN
# 112          flare.Public Protection.District Attorney           NaN
# 113       flare.Public Protection.Emergency Management           NaN
#
#                                            description     change  \
# 0                                                  NaN        NaN
# ...
