# %% [markdown]
# # Notebook for updating police incidents daily

# %%
import pandas as pd
import requests
import requests_cache
import time
from io import StringIO
from datetime import datetime, timedelta
import json

pd.set_option('display.max_rows', 1000) 
pd.set_option('display.max_columns', 1000)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## Getting all crime data from the previous day

# %% [markdown]
# #### Right now I haven't handled duplicates. Simple fix later, once we decide how to

# %% [markdown]
# - request only the previous day's crimes.
# - update according to the date
# - concat to the existing df, make sure there aren't any duplicates

# %%
# load our master dataset of crimes
crimes_df = pd.read_csv("crimes_updated.csv")
crimes_df.head(2)
# Out:
#          row_id        incident_datetime            incident_date  \
# 0  150744327170  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
# 1  150728309320  2025-08-25T08:40:00.000  2025-08-25T00:00:00.000
#
#   incident_time  incident_year incident_day_of_week          report_datetime  \
# 0         11:22           2025              Tuesday  2025-08-26T11:22:00.000
# 1         08:40           2025               Monday  2025-08-26T10:03:00.000
#
#    incident_id  incident_number   cad_number report_type_code  \
# 0      1507443        250478275  252381401.0               II
# 1      1507283        250478015  252381142.0               II
#
#   report_type_description  filed_online  incident_code    incident_category  \
# 0                 Initial           NaN          27170  Other Miscellaneous
# 1                 Initial           NaN           9320                Fraud
#
#   incident_subcategory  \
# 0                Other
# 1                Fraud
#
#                                         incident_description  \
# 0  Resisting, Delaying, or Obstructing  Peace Officer Duties
# 1   Access Card, incl. Credit, Phone, ATM, Fraudulent Use of
#
#              resolution                                   intersection  \
# 0  Cite or Arrest Adult                             16TH ST \ WIESE ST
# 1        Open or Active  MARKET ST \ SOUTH VAN NESS AVE \ VAN NESS AVE
#
#         cnn police_district analysis_neighborhood  supervisor_district  \
# 0  24180000         Mission               Mission                    9
# 1  30748000        Southern               Mission                    6
#
#    supervisor_district_2012   latitude   longitude  \
# 0                         9  37.765003 -122.420479
# 1                         6  37.775146 -122.419258
#
#                                  point               data_as_of  \
# 0  POINT (-122.420478821 37.765003204)  2025-08-27T09:38:07.000
# 1  POINT (-122.419258118 37.775146484)  2025-08-27T09:38:07.000
#
#             data_loaded_at
# 0  2025-08-28T09:53:00.000
# 1  2025-08-28T09:53:00.000

# %%
yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')

# debugging for a couple weeks, can remove later
print(f"Fetching data for: {yesterday}")
# Out:
# Fetching data for: 2025-11-18

# %%
url = "https://data.sfgov.org/resource/wg3w-h783.csv"

# %%
# parameters for the url. Easier if we filter in the request itself because of the sheer volume of reports. 
# filters with date range for yesterday

filters = {
    'analysis_neighborhood': 'Mission',
    'report_type_description': 'Initial',
    '$where': f"incident_date >= '{yesterday}T00:00:00' AND incident_date < '{yesterday}T23:59:59'"
}

# %%
response = requests.get(url, params=filters)

# %%
if response.status_code == 200:
    
    new_data = pd.read_csv(StringIO(response.text))
    print("New records fetched:", len(new_data))

else:
    print(f"Error: {response.status_code}")
# Out:
# New records fetched: 30

# %%
# concat
crimes_df = pd.concat([crimes_df, new_data], ignore_index=True)

# remove duplicates
# crimes_df = crimes_df.drop_duplicates(subset=['incident_id'], keep='first')

# %%
# Save updated data
crimes_df.to_csv('crimes_updated.csv', index=False)
crimes_df.head()

# %% [markdown]
# ##### @Kelly: Thoughts on how we should deal with similar incident numbers? See below for one incident being cited for multiple violations.

# %%
crimes_df[crimes_df["incident_id"]== 1507443]
# Out:
#             row_id        incident_datetime            incident_date  \
# 0     150744327170  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
# 32    150744363010  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
# 38    150744326170  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
# 2200  150744327170  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
# 2230  150744363010  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
# 2236  150744326170  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
#
#      incident_time  incident_year incident_day_of_week  \
# 0            11:22           2025              Tuesday
# 32           11:22           2025              Tuesday
# 38           11:22           2025              Tuesday
# 2200         11:22           2025              Tuesday
# 2230         11:22           2025              Tuesday
# 2236         11:22           2025              Tuesday
#
#               report_datetime  incident_id  incident_number   cad_number  \
# 0     2025-08-26T11:22:00.000      1507443        250478275  252381401.0
# 32    2025-08-26T11:22:00.000      1507443        250478275  252381401.0
# 38    2025-08-26T11:22:00.000      1507443        250478275  252381401.0
# 2200  2025-08-26T11:22:00.000      1507443        250478275  252381401.0
# 2230  2025-08-26T11:22:00.000      1507443        250478275  252381401.0
# 2236  2025-08-26T11:22:00.000      1507443        250478275  252381401.0
#
#      report_type_code report_type_description  filed_online  incident_code  \
# 0                  II                 Initial           NaN          27170
# 32                 II                 Initial           NaN          63010
# 38                 II                 Initial           NaN          26170
# 2200               II                 Initial           NaN          27170
# 2230               II                 Initial           NaN          63010
# 2236               II                 Initial           NaN          26170
#
#         incident_category incident_subcategory  \
# 0     Other Miscellaneous                Other
# 32                Warrant                Other
# 38    Other Miscellaneous                Other
# 2200  Other Miscellaneous                Other
# 2230              Warrant                Other
# 2236  Other Miscellaneous                Other
#
#                                            incident_description  \
# 0     Resisting, Delaying, or Obstructing  Peace Officer Duties
# 32                             Warrant Arrest, Local SF Warrant
# 38                                          Probation Violation
# 2200  Resisting, Delaying, or Obstructing  Peace Officer Duties
# 2230                           Warrant Arrest, Local SF Warrant
# 2236                                        Probation Violation
#
#                 resolution        intersection       cnn police_district  \
# 0     Cite or Arrest Adult  16TH ST \ WIESE ST  24180000         Mission
# 32    Cite or Arrest Adult  16TH ST \ WIESE ST  24180000         Mission
# 38    Cite or Arrest Adult  16TH ST \ WIESE ST  24180000         Mission
# 2200  Cite or Arrest Adult  16TH ST \ WIESE ST  24180000         Mission
# 2230  Cite or Arrest Adult  16TH ST \ WIESE ST  24180000         Mission
# 2236  Cite or Arrest Adult  16TH ST \ WIESE ST  24180000         Mission
#
#      analysis_neighborhood  supervisor_district  supervisor_district_2012  \
# 0                  Mission                    9                         9
# 32                 Mission                    9                         9
# 38                 Mission                    9                         9
# 2200               Mission                    9                         9
# 2230               Mission                    9                         9
# 2236               Mission                    9                         9
#
#        latitude   longitude                                point  \
# 0     37.765003 -122.420479  POINT (-122.420478821 37.765003204)
# 32    37.765003 -122.420479  POINT (-122.420478821 37.765003204)
# 38    37.765003 -122.420479  POINT (-122.420478821 37.765003204)
# 2200  37.765003 -122.420479  POINT (-122.420478821 37.765003204)
# 2230  37.765003 -122.420479  POINT (-122.420478821 37.765003204)
# 2236  37.765003 -122.420479  POINT (-122.420478821 37.765003204)
#
#                    data_as_of           data_loaded_at
# 0     2025-08-27T09:38:07.000  2025-08-28T09:53:00.000
# 32    2025-08-27T09:38:07.000  2025-08-28T09:53:00.000
# 38    2025-08-27T09:38:07.000  2025-08-28T09:53:00.000
# 2200  2025-08-27T09:38:07.000  2025-08-28T09:53:00.000
# 2230  2025-08-27T09:38:07.000  2025-08-28T09:53:00.000
# 2236  2025-08-27T09:38:07.000  2025-08-28T09:53:00.000

# %% [markdown]
# ## Add code for restricting geography

# %%
crimes_df = pd.read_csv("crimes_updated.csv")
crimes_df.head(2)
# Out:
#          row_id        incident_datetime            incident_date  \
# 0  150744327170  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
# 1  150728309320  2025-08-25T08:40:00.000  2025-08-25T00:00:00.000
#
#   incident_time  incident_year incident_day_of_week          report_datetime  \
# 0         11:22           2025              Tuesday  2025-08-26T11:22:00.000
# 1         08:40           2025               Monday  2025-08-26T10:03:00.000
#
#    incident_id  incident_number   cad_number report_type_code  \
# 0      1507443        250478275  252381401.0               II
# 1      1507283        250478015  252381142.0               II
#
#   report_type_description  filed_online  incident_code    incident_category  \
# 0                 Initial           NaN          27170  Other Miscellaneous
# 1                 Initial           NaN           9320                Fraud
#
#   incident_subcategory  \
# 0                Other
# 1                Fraud
#
#                                         incident_description  \
# 0  Resisting, Delaying, or Obstructing  Peace Officer Duties
# 1   Access Card, incl. Credit, Phone, ATM, Fraudulent Use of
#
#              resolution                                   intersection  \
# 0  Cite or Arrest Adult                             16TH ST \ WIESE ST
# 1        Open or Active  MARKET ST \ SOUTH VAN NESS AVE \ VAN NESS AVE
#
#         cnn police_district analysis_neighborhood  supervisor_district  \
# 0  24180000         Mission               Mission                    9
# 1  30748000        Southern               Mission                    6
#
#    supervisor_district_2012   latitude   longitude  \
# 0                         9  37.765003 -122.420479
# 1                         6  37.775146 -122.419258
#
#                                  point               data_as_of  \
# 0  POINT (-122.420478821 37.765003204)  2025-08-27T09:38:07.000
# 1  POINT (-122.419258118 37.775146484)  2025-08-27T09:38:07.000
#
#             data_loaded_at
# 0  2025-08-28T09:53:00.000
# 1  2025-08-28T09:53:00.000

# %% [markdown]
# ## Calendar Map

# %%
pwd
# Out:
# '/Users/anushasubramanian/Desktop/Mission_Local/2025-graphics/docs/16th-dashboard'

# %%
# Convert incident_date to datetime
crimes_df['incident_date'] = pd.to_datetime(crimes_df['incident_date'])

# Filter to last 6 months
from datetime import datetime, timedelta
six_months_ago = datetime.now() - timedelta(days=180)
crimes_df = crimes_df[crimes_df['incident_date'] >= six_months_ago]

# Replace NaN in incident_category with "Unknown"
crimes_df['incident_category'] = crimes_df['incident_category'].fillna('Unknown')

# Group by date and get crime categories for each day
calendar_export = crimes_df.groupby('incident_date').agg({
    'incident_category': list,
}).reset_index()

# Add count of incidents
calendar_export['count'] = calendar_export['incident_category'].apply(len)

calendar_export['incident_date'] = calendar_export['incident_date'].dt.strftime('%Y-%m-%d')

calendar_export = calendar_export.rename(columns={
    'incident_date': 'date',
    'incident_category': 'types'
})

# Reorder columns
calendar_export = calendar_export[['date', 'count', 'types']]

calendar_data = calendar_export.to_dict('records')

# Save as json
with open('calendar_map/calendar_data.json', 'w') as f:
    json.dump(calendar_data, f, indent=2)

# %% [markdown]
# ## Getting the master list of current data - 69k records since 2018

# %% [markdown]
# Date of last run: Until Nov.18, 2025
#
# - Only for Mission district
# - Only initial reports, not copologic
#
# We only run this **once** to get all the data till today to create our master list that we will then update.
#
#
# @Kelly: do you want to ignore incidents reported that were ongoing and only consider the ones resulting in arrests and citation?

# %%
# # Same concept as above 

# url = "https://data.sfgov.org/resource/wg3w-h783.csv"

# all_data = []
# offset = 0
# limit = 1000  # this is the max you get if you don't paginate

# # parameters for the url. Easier if we filter in the request itself because of the sheer volume of reports. 
# filters = {
#     '$limit': limit,
#     '$offset': offset,
#     'analysis_neighborhood': 'Mission',  
#     'report_type_description': 'Initial'  
# }

# while True:
#     # Update offset for pagination
#     filters['$offset'] = offset
    
#     # Make request
#     response = requests.get(url, params=filters)
    
#     if response.status_code != 200:
#         print(f"Error: {response.status_code}")
#         break
    
#     # parse CSV
#     chunk_df = pd.read_csv(StringIO(response.text))
    
#     # check if we got any data. If we got nothing, we've reached the end of the list
#     if len(chunk_df) == 0:
#         break
    
#     # creating a list of dfs to concat at the end
#     all_data.append(chunk_df)
    
#     # if we got fewer records than the limit, we've reached the end
#     if len(chunk_df) < limit:
#         break
    
#     # update offset and wait so we don't timeout accidentally
#     offset += limit
#     time.sleep(0.5)

# # concat
# crimes_df = pd.concat(all_data, ignore_index=True) if all_data else pd.DataFrame()

# print(f"Total records fetched: {len(crimes_df)}")
    
# crimes_df.head()
# Out:
# Total records fetched: 68980
#          row_id        incident_datetime            incident_date  \
# 0  150744327170  2025-08-26T11:22:00.000  2025-08-26T00:00:00.000
# 1  150728309320  2025-08-25T08:40:00.000  2025-08-25T00:00:00.000
# 2  150744562050  2025-08-26T16:16:00.000  2025-08-26T00:00:00.000
# 3  150742216710  2025-08-26T12:49:00.000  2025-08-26T00:00:00.000
# 4  150621016710  2025-08-21T13:35:00.000  2025-08-21T00:00:00.000
#
#   incident_time  incident_year incident_day_of_week          report_datetime  \
# 0         11:22           2025              Tuesday  2025-08-26T11:22:00.000
# 1         08:40           2025               Monday  2025-08-26T10:03:00.000
# 2         16:16           2025              Tuesday  2025-08-26T16:16:00.000
# 3         12:49           2025              Tuesday  2025-08-26T12:49:00.000
# 4         13:35           2025             Thursday  2025-08-21T13:35:00.000
#
#    incident_id  incident_number   cad_number report_type_code  \
# 0      1507443        250478275  252381401.0               II
# 1      1507283        250478015  252381142.0               II
# 2      1507445        250479013  252382436.0               II
# 3      1507422        250478504  252381724.0               II
# 4      1506210        250468113  252332081.0               II
#
#   report_type_description  filed_online  incident_code    incident_category  \
# 0                 Initial           NaN          27170  Other Miscellaneous
# 1                 Initial           NaN           9320                Fraud
# 2                 Initial           NaN          62050              Warrant
# 3                 Initial           NaN          16710         Drug Offense
# 4                 Initial           NaN          16710         Drug Offense
#
#   incident_subcategory  \
# 0                Other
# 1                Fraud
# 2              Warrant
# 3       Drug Violation
# 4       Drug Violation
#
#                                         incident_description  \
# 0  Resisting, Delaying, or Obstructing  Peace Officer Duties
# 1   Access Card, incl. Credit, Phone, ATM, Fraudulent Use of
# 2            Warrant Arrest, Enroute To Outside Jurisdiction
# 3                     Narcotics Paraphernalia, Possession of
# 4                     Narcotics Paraphernalia, Possession of
#
#              resolution                                   intersection  \
# 0  Cite or Arrest Adult                             16TH ST \ WIESE ST
# 1        Open or Active  MARKET ST \ SOUTH VAN NESS AVE \ VAN NESS AVE
# 2  Cite or Arrest Adult                          17TH ST \ VALENCIA ST
# 3  Cite or Arrest Adult                           15TH ST \ MISSION ST
# 4  Cite or Arrest Adult                           14TH ST \ JULIAN AVE
#
#         cnn police_district analysis_neighborhood  supervisor_district  \
# 0  24180000         Mission               Mission                    9
# 1  30748000        Southern               Mission                    6
# 2  24174000         Mission               Mission                    9
# 3  24171000         Mission               Mission                    9
# 4  24373000         Mission               Mission                    9
#
#    supervisor_district_2012   latitude   longitude  \
# 0                         9  37.765003 -122.420479
# 1                         6  37.775146 -122.419258
# 2                         9  37.763298 -122.421730
# 3                         9  37.766674 -122.419823
# 4                         9  37.768200 -122.421211
#
#                                  point               data_as_of  \
# 0  POINT (-122.420478821 37.765003204)  2025-08-27T09:38:07.000
# 1  POINT (-122.419258118 37.775146484)  2025-08-27T09:38:07.000
# 2  POINT (-122.421730042 37.763298035)  2025-08-27T09:38:07.000
# 3  POINT (-122.419822693 37.766674042)  2025-08-27T09:38:07.000
# 4  POINT (-122.421211243 37.768199921)  2025-08-27T09:38:07.000
#
#             data_loaded_at
# 0  2025-08-28T09:53:00.000
# 1  2025-08-28T09:53:00.000
# 2  2025-08-28T09:53:00.000
# 3  2025-08-28T09:53:00.000
# 4  2025-08-28T09:53:00.000

# %%
crimes_df.to_csv("crimes_updated.csv", index = False)
